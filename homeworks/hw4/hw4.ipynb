# %% [markdown]
# HU Extension Assignment 04 E89 Deep Learning
# ===
# Due by 11:59 AM EST on Saturday, 02/24/208

# %% [markdown]
# Problem 1.
# ---
# Please find attached one file from Google’s tutorials sets. I used that file corrected_MNIST.py for preparation of my notes. If you read the file carefully you will see that you can run it in at least two modes. The way it is setup now it goes through a loop in which it selects one of three learning rates and one of four neural network architecture. Those architectures contain 1 or 2 convolutional layers and one or two fully connected layers. All in all the program goes through 12 combinations of learning rates and different architectures. Below I am providing an image presenting network accuracy as the network is trained. You are welcome to run this program as is. On my machine Windows 10 Pro machine with i7 processor with 8 cores, 32 GB of RAM and without GPU this 12 network runs lasted 1 h and 40 minutes.
#
# Rather than going through all 12 combinations I recommend you run a CNN with the learning rate of $10^{-2}$ and two convolutional layers and two fully connected layers. Capture network accuracy and cross entropy as it passes through the training process. (25%)

# %% [markdown]
# Solution:
# ---
#
# Learning rate: 1E-2
#
# Accuracy and Cross Entropy was captured every 5 batches
#
# NOTE: Data downloaded from tensorboard for this CNN training run
#
# Accuracy and Cross Entropy Table
# ---
#
# |Wall time|Step|Accuracy|Cross Entropy|
# |:-|:-|:-|:-|
# |1519516967|0|0.2400|9.0825|
# |1519516969|5|0.0800|5.1487|
# |1519516970|10|0.1200|2.6199|
# |1519516971|15|0.0800|2.4034|
# |1519516972|20|0.1400|2.2723|
# |1519516974|25|0.2000|2.1410|
# |1519516975|30|0.4800|1.7821|
# |1519516976|35|0.5700|1.4909|
# |1519516977|40|0.6800|1.1515|
# |1519516978|45|0.7800|0.7177|
# |1519516979|50|0.7800|0.5557|
# |1519516980|55|0.8100|0.4495|
# |1519516981|60|0.8500|0.6346|
# |1519516982|65|0.8600|0.3613|
# |1519516983|70|0.9100|0.3165|
# |1519516984|75|0.9100|0.3491|
# |1519516985|80|0.9500|0.2244|
# |1519516986|85|0.9300|0.2661|
# |1519516987|90|0.9200|0.2895|
# |1519516988|95|0.9400|0.1811|
# |1519516989|100|0.9500|0.1264|
# |1519516990|105|0.9400|0.1788|
# |1519516991|110|0.9300|0.2461|
# |1519516992|115|0.9300|0.2272|
# |1519516993|120|0.9000|0.2994|
# |1519516994|125|0.9200|0.2830|
# |1519516995|130|0.9100|0.2985|
# |1519516997|135|0.9500|0.1838|
# |1519516998|140|0.9500|0.1494|
# |1519516999|145|0.9800|0.0665|
# |1519517000|150|0.9100|0.3056|
# |1519517001|155|0.9600|0.1139|
# |1519517002|160|0.9600|0.1849|
# |1519517003|165|0.9100|0.2336|
# |1519517004|170|0.9300|0.2746|
# |1519517005|175|0.9500|0.1264|
# |1519517006|180|0.9700|0.1246|
# |1519517007|185|0.9600|0.1254|
# |1519517008|190|0.9500|0.1619|
# |1519517010|195|0.9500|0.1099|
# |1519517011|200|0.9700|0.1172|
# |1519517012|205|0.9400|0.1588|
# |1519517013|210|0.9800|0.1190|
# |1519517014|215|0.9600|0.1272|
# |1519517015|220|0.9400|0.2576|
# |1519517016|225|0.9600|0.1560|
# |1519517017|230|0.9500|0.1414|
# |1519517339|1730|0.9900|0.0183|
# |1519517340|1735|0.9800|0.2302|
# |1519517341|1740|0.9800|0.0902|
# |1519517342|1745|0.9900|0.0417|
# |1519517343|1750|1.0000|0.0099|
# |1519517344|1755|1.0000|0.0204|
# |1519517345|1760|0.9800|0.0295|
# |1519517346|1765|0.9900|0.0296|
# |1519517347|1770|0.9900|0.0229|
# |1519517349|1775|1.0000|0.0109|
# |1519517350|1780|1.0000|0.0052|
# |1519517351|1785|0.9600|0.0933|
# |1519517352|1790|0.9900|0.0363|
# |1519517353|1795|0.9700|0.0426|
# |1519517354|1800|1.0000|0.0105|
# |1519517355|1805|1.0000|0.0184|
# |1519517356|1810|0.9600|0.0604|
# |1519517357|1815|0.9800|0.0739|
# |1519517358|1820|0.9900|0.0327|
# |1519517359|1825|0.9900|0.0349|
# |1519517360|1830|0.9800|0.0358|
# |1519517361|1835|0.9900|0.0341|
# |1519517362|1840|0.9900|0.0178|
# |1519517363|1845|0.9800|0.0549|
# |1519517364|1850|0.9900|0.0476|
# |1519517365|1855|0.9800|0.0703|
# |1519517366|1860|1.0000|0.0091|
# |1519517367|1865|0.9700|0.0556|
# |1519517368|1870|0.9900|0.0284|
# |1519517369|1875|0.9800|0.0531|
# |1519517370|1880|1.0000|0.0022|
# |1519517371|1885|1.0000|0.0183|
# |1519517372|1890|1.0000|0.0209|
# |1519517374|1895|1.0000|0.0078|
# |1519517375|1900|0.9900|0.0302|
# |1519517376|1905|1.0000|0.0075|
# |1519517377|1910|0.9900|0.0421|
# |1519517378|1915|0.9600|0.0938|
# |1519517379|1920|0.9900|0.0317|
# |1519517380|1925|0.9700|0.0809|
# |1519517381|1930|1.0000|0.0040|
# |1519517382|1935|0.9700|0.0794|
# |1519517383|1940|0.9700|0.1234|
# |1519517384|1945|0.9800|0.0439|
# |1519517385|1950|0.9800|0.0387|
# |1519517386|1955|0.9800|0.0717|
# |1519517387|1960|1.0000|0.0166|
# |1519517388|1965|0.9900|0.0480|
# |1519517389|1970|1.0000|0.0120|
# |1519517390|1975|1.0000|0.0085|
# |1519517391|1980|0.9800|0.0628|
# |1519517392|1985|0.9900|0.0306|
# |1519517394|1990|0.9900|0.0345|
# |1519517395|1995|0.9800|0.0720|

# %% [markdown]
# Problem 2.
# ---
# Now that you are convinced that your network works make an attempt to establish an optimal value of the learning rate. Examine several (randomly selected) learning rates in the interval between $10^{−1}$ and $10^{−3}$. Create a diagram with duration of the run and the final accuracy as two coordinate axes. Present each run as a point in the diagram. Label each point with its learning rate. Determine the “final” accuracy of your model as the average accuracy over all test samples. Just out of curiosity, capture an average accuracy towards the end of network training as well. You noticed that the accuracy we plot during the training is a stochastic (oscillating) function. To get a single number, average that accuracy over either a fixed period of 2 minutes (120 seconds) or over the last 50 batches. Please notice that the current program prints accuracy every 5 batches.
# (25%)

# %% [markdown]
# Solution:
# ---
# To capture 'final' accuracy which is the accuracy of predictions for the test samples
# following lines of code were added as the training process is done
# ```
# test_accuracy = sess.run(accuracy, feed_dict={x: mnist.test.images[:1024], y: mnist.test.labels[:1024]})
# print("Test accuracy is {}".format(test_accuracy))
# ```

# %% [markdown]
# Randomly selected three learning rate:
# * 8E-2
# * 2E-2
# * 5E-3

# %% [markdown]
# TensorBoard graph for training phase:
# ![hw4_p2.png](hw4_p2.png)

# %%
# Plotted for each learning rate:
#  - 'Final' Accuracy predicting the test data set
#  - Average training accuracy predicting the last 50 batches of training data
# %matplotlib inline
import matplotlib.pyplot as plt
nmist_runs = {
    # "Learning Rate" : (DurationInSeconds, TestAccuracy)
    "LR 2E-2": (389, 0.9765625),
    "LR 8E-2": (394, 0.10546875),
    "LR 5E-3": (388, 0.9892578125)
}
plt.figure()
for k, v in nmist_runs.items():
    plt.plot(v[0], v[1], 'x', label=k)
plt.legend(title='Learning Rate')
plt.xlabel("Training Duration in Seconds")
plt.ylabel("Final Accuracy")
# Out:
# Text(0,0.5,'Final Accuracy')

# %%
# Recording the training accuracy towards the end of the training period (Average of last 50 batches)
avg_last_50_batch_train_lr_2E_2 = 0.9830
avg_last_50_batch_train_lr_8E_2 = 0.1130
avg_last_50_batch_train_lr_5E_3 = 0.9880
avg_last_50_batch = {
    # "Learning Rate" : average last 50 batch train
    "LR 2E-2": 0.9830,
    "LR 8E-2": 0.1130,
    "LR 5E-3": 0.9880
}
for k,v in avg_last_50_batch.items():
    print("Learning Rate: {0}, Avg Training Accuracy of Last 50 batches: {1}".format(k, v))
# Out:
# Learning Rate: LR 2E-2, Avg Training Accuracy of Last 50 batches: 0.983
# Learning Rate: LR 8E-2, Avg Training Accuracy of Last 50 batches: 0.113
# Learning Rate: LR 5E-3, Avg Training Accuracy of Last 50 batches: 0.988

# %% [markdown]
# In conclusion, learning rate $5*10^{-3}$ has the best result.

# %% [markdown]
# Problem 3.
# ---
# Select the most optimal value of the learning rate from Problem 2 and replace the MomentumOptimizer used in the code with AdamOptimizer. You might want to search through TensorFlow documentation and Wikipedia or just Internet to discover what is the difference between the two. Please report the difference in execution time and accuracy if any.
# (25%)

# %% [markdown]
# Solution:
# ---
# Replaced the optimizer with the following code
# ```
# train_step = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(xent)
# ```
# Where learning rate was the winner from P2: $5*10^{-3}$
#
# |Optimizer|Duration in Seconds|Average Training Accurracy(Last 50 Batches)|Testing Accurracy
# |:-|:-|:-|:-|
# |MomentumOptimizer|388|0.9880|0.9893|
# |AdamOptimizer|383|0.1240|0.1055|

# %% [markdown]
# Problem 4.
# ---
# For the faster network from problem 3, try running the network by initializing the initial values of all weights 𝑊 to zero. Note that in the current code weights 𝑊 are initialized by the truncated normal distribution. Subsequently, initialize all weights 𝑊 with a small positive number, for example 0.05. Report on the network training times and final accuracies for all three combinations of initialization values. (25%)

# %% [markdown]
# Solution:
# ---
# Learning rate : $5*10^{-3}$
# Optimizer: MomentumOptimizer
#
# |Initial Weights|Duration in Seconds|Average Training Accurracy(Last 50 Batches)|Testing Accurracy
# |:-|:-|:-|:-|
# |Truncated Normal Distribution|388|0.9880|0.9893|
# |0s|387|0.9700|0.9775|
# |0.5s|374|0.1110|0.1270|
